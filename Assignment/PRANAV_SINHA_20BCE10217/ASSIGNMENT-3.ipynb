# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# 2. Load the dataset into the tool

# %%
data=pd.read_csv("Housing.csv")

# %%
data.shape
# Out:
# (545, 12)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
data.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 540              no              no        2      unfurnished
# 541              no              no        0   semi-furnished
# 542              no              no        0      unfurnished
# 543              no              no        0        furnished
# 544              no              no        0      unfurnished

# %% [markdown]
# 3. Perform Below Visualizations.
# * Univariate Analysis
# * Bi-Variate Analysis
# * Multi-Variate Analysis

# %%
# univariate analysis
#histogram
import matplotlib.pyplot as plt

plt.hist(data['area'],bins=10)
plt.xlabel('HOUSING AREA')
plt.ylabel('FREQUENCY')
plt.show()

# %%
#box plot

plt.boxplot(data['area'])
plt.ylabel('area')
plt.show()

# %%
#density plot
import seaborn as sns
sns.kdeplot(data["area"])
# Out:
# <Axes: xlabel='area', ylabel='Density'>

# %%
#piechart
plt.pie(data["furnishingstatus"].value_counts(),labels=["unfurnished","semi-furnished","furnished"],autopct='%1.1f')
plt.show()

# %% [markdown]
# Bi-variate analysis

# %%
#scater plot
plt.scatter(data["area"],data["price"])
plt.show()

# %%
plt.bar(data["bedrooms"],data["price"])
plt.show()

# %% [markdown]
# multi-variate

# %%
#heat map
corr_matrix=data[["area","bedrooms","parking","price"]].corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
#stackedbar chart
plt.bar(data['bedrooms'], data['price'], color='b', label='bedrooms')
plt.bar(data['parking'], data['price'], color='g', label='parking')
# plt.bar(data['area'],data['price'],color='r',label="area")
# Out:
# <BarContainer object of 545 artists>

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
data.mean()
# Out:
# <ipython-input-17-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-18-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
data.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
data.std()
# Out:
# <ipython-input-20-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %%
data.var()
# Out:
# <ipython-input-21-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
data.min()
# Out:
# price                 1750000
# area                     1650
# bedrooms                    1
# bathrooms                   1
# stories                     1
# mainroad                   no
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning            no
# parking                     0
# furnishingstatus    furnished
# dtype: object

# %%
data.max()
# Out:
# price                  13300000
# area                      16200
# bedrooms                      6
# bathrooms                     4
# stories                       4
# mainroad                    yes
# guestroom                   yes
# basement                    yes
# hotwaterheating             yes
# airconditioning             yes
# parking                       3
# furnishingstatus    unfurnished
# dtype: object

# %% [markdown]
# 5. Check for Missing values and deal with them.

# %%
data.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
#as there are no null values no need of filling them

# %% [markdown]
# 6. Find the outliers and replace them outliers

# %%
columns=["area","bedrooms","bathrooms","stories","parking"]
for column in columns:
  q1=data[column].quantile(0.25)
  q3=data[column].quantile(0.75)
  IQR=q3-q1
  lowerbound=q1-(1.5*IQR)
  upperbound=q3+(1.5*IQR)
  # print(column,q1,q3,IQR,lowerbound,upperbound)
  #outliers
  outliers = data[(data[column] < lowerbound) | (data[column] > upperbound)]
  # print(column,outliers)
  #replacing with median
  data.loc[(data[column] < lowerbound) | (data[column] > upperbound), column] = data[column].median()

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          1        2      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        0        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        0        furnished
# 4              no             yes        2        furnished

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
# categorical_columns = data.select_dtypes(include=['object', 'category']).columns
# print(categorical_columns)

categorical_columns=['mainroad', 'guestroom', 'basement', 'hotwaterheating',
       'airconditioning', 'furnishingstatus']

# %%
#one hot encoding

# if 'prices' in categorical_columns:
#     categorical_columns.remove('prices')

# encoded_data=pd.get_dummies(data=data,columns=categorical_columns)
# encoded_data

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in categorical_columns:
    encoded_values = label_encoder.fit_transform(data[column])
    data[column] = encoded_values

data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          1        2         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 0         0                0                1        2                 0
# 1         0                0                1        0                 0
# 2         1                0                0        2                 1
# 3         1                0                1        0                 0
# 4         1                0                1        2                 0

# %% [markdown]
# 8. Split the data
# into dependent and independent variables.

# %%
x=data.drop(columns="price",axis=1)
y=data["price"]

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          1        2         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %% [markdown]
# 9. Scale the independent variables

# %%
#using standardization
from sklearn.preprocessing import StandardScaler

scale=StandardScaler()


scaled_x=scale.fit_transform(x)

# %%
scaled_x
# Out:
# array([[ 1.33470625,  1.64762051,  1.47243614, ...,  1.4726183 ,
#          1.72906501, -1.40628573],
#        [ 2.17446697,  1.64762051, -0.57470084, ...,  1.4726183 ,
#         -0.79056181, -1.40628573],
#        [ 2.71976613,  0.12566597,  1.47243614, ..., -0.67906259,
#          1.72906501, -0.09166185],
#        ...,
#        [-0.73743057, -1.39628857, -0.57470084, ..., -0.67906259,
#         -0.79056181,  1.22296203],
#        [-1.12459298,  0.12566597, -0.57470084, ..., -0.67906259,
#         -0.79056181, -1.40628573],
#        [-0.61201177,  0.12566597, -0.57470084, ..., -0.67906259,
#         -0.79056181,  1.22296203]])

# %% [markdown]
# 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (381, 11)

# %%
x_test.shape
# Out:
# (164, 11)

# %%
y_train.shape
# Out:
# (381,)

# %%
y_test.shape
# Out:
# (164,)

# %% [markdown]
# 11. Build the Model

# %%
#using linear regression

from sklearn.linear_model import LinearRegression

model1=LinearRegression()

# %% [markdown]
# 12. Train the Model

# %%
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 13. Test the Model
#
# 14. Measure the performance using Metrics

# %%
m1_pred=model1.predict(x_test)

# %%
from sklearn.metrics import r2_score

acc=r2_score(m1_pred,y_test)

acc
# Out:
# 0.42098957900660716

# %% [markdown]
# using ridge regression

# %%
from sklearn.linear_model import Ridge

rd=Ridge()
rd.fit(x_train,y_train)

pred2=rd.predict(x_test)

acc2=rd.score(x_test,y_test)

acc2
# Out:
# 0.5835264051189999

# %% [markdown]
# using laso

# %%
from sklearn.linear_model import Lasso


lasso_regressor = Lasso()


lasso_regressor.fit(x_train, y_train)

# Predict on the test set
y_pred = lasso_regressor.predict(x_test)


# Calculate the R-squared score
r2 = lasso_regressor.score(x_test, y_test)
print("R-squared:", r2)
# Out:
# R-squared: 0.5816163614716711

# %% [markdown]
# using multiple regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Create an instance of the LinearRegression model
regressor = LinearRegression()

# Fit the model to the training data
regressor.fit(x_train, y_train)

# Predict on the test set
y_pred = regressor.predict(x_test)

# Calculate the R-squared score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# R-squared: 0.5816155217409871
